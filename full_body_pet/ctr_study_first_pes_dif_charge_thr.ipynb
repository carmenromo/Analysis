# %%
import os
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
filepath = '/data5/users/carmenromo/PETALO/full-body-PET/CTR/data_ctr_study_first_pes_dif_charge_thr/'

timestamp_thr   = [0, 0.5, 1.0, 1.5, 2.0, 2.5]
num_of_init_pes = [1, 2, 3, 5, 8, 10, 12, 14, 16]

time_diff1_00, time_diff1_01, time_diff1_02 = np.array([]), np.array([]), np.array([])
time_diff1_03, time_diff1_04, time_diff1_05 = np.array([]), np.array([]), np.array([])
time_diff1_10, time_diff1_11, time_diff1_12 = np.array([]), np.array([]), np.array([])
time_diff1_13, time_diff1_14, time_diff1_15 = np.array([]), np.array([]), np.array([])
time_diff1_20, time_diff1_21, time_diff1_22 = np.array([]), np.array([]), np.array([])
time_diff1_23, time_diff1_24, time_diff1_25 = np.array([]), np.array([]), np.array([])
time_diff1_30, time_diff1_31, time_diff1_32 = np.array([]), np.array([]), np.array([])
time_diff1_33, time_diff1_34, time_diff1_35 = np.array([]), np.array([]), np.array([]) 
time_diff1_40, time_diff1_41, time_diff1_42 = np.array([]), np.array([]), np.array([]) 
time_diff1_43, time_diff1_44, time_diff1_45 = np.array([]), np.array([]), np.array([]) 
time_diff1_50, time_diff1_51, time_diff1_52 = np.array([]), np.array([]), np.array([]) 
time_diff1_53, time_diff1_54, time_diff1_55 = np.array([]), np.array([]), np.array([]) 
time_diff1_60, time_diff1_61, time_diff1_62 = np.array([]), np.array([]), np.array([])
time_diff1_63, time_diff1_64, time_diff1_65 = np.array([]), np.array([]), np.array([])
time_diff1_70, time_diff1_71, time_diff1_72 = np.array([]), np.array([]), np.array([])
time_diff1_73, time_diff1_74, time_diff1_75 = np.array([]), np.array([]), np.array([])
time_diff1_80, time_diff1_81, time_diff1_82 = np.array([]), np.array([]), np.array([])
time_diff1_83, time_diff1_84, time_diff1_85 = np.array([]), np.array([]), np.array([])

time_diff2_00, time_diff2_01, time_diff2_02 = np.array([]), np.array([]), np.array([])
time_diff2_03, time_diff2_04, time_diff2_05 = np.array([]), np.array([]), np.array([])
time_diff2_10, time_diff2_11, time_diff2_12 = np.array([]), np.array([]), np.array([])
time_diff2_13, time_diff2_14, time_diff2_15 = np.array([]), np.array([]), np.array([])
time_diff2_20, time_diff2_21, time_diff2_22 = np.array([]), np.array([]), np.array([])
time_diff2_23, time_diff2_24, time_diff2_25 = np.array([]), np.array([]), np.array([])
time_diff2_30, time_diff2_31, time_diff2_32 = np.array([]), np.array([]), np.array([])
time_diff2_33, time_diff2_34, time_diff2_35 = np.array([]), np.array([]), np.array([]) 
time_diff2_40, time_diff2_41, time_diff2_42 = np.array([]), np.array([]), np.array([]) 
time_diff2_43, time_diff2_44, time_diff2_45 = np.array([]), np.array([]), np.array([]) 
time_diff2_50, time_diff2_51, time_diff2_52 = np.array([]), np.array([]), np.array([]) 
time_diff2_53, time_diff2_54, time_diff2_55 = np.array([]), np.array([]), np.array([]) 
time_diff2_60, time_diff2_61, time_diff2_62 = np.array([]), np.array([]), np.array([])
time_diff2_63, time_diff2_64, time_diff2_65 = np.array([]), np.array([]), np.array([])
time_diff2_70, time_diff2_71, time_diff2_72 = np.array([]), np.array([]), np.array([])
time_diff2_73, time_diff2_74, time_diff2_75 = np.array([]), np.array([]), np.array([])
time_diff2_80, time_diff2_81, time_diff2_82 = np.array([]), np.array([]), np.array([])
time_diff2_83, time_diff2_84, time_diff2_85 = np.array([]), np.array([]), np.array([])


for filename in os.listdir(filepath):
    if filename.endswith('2_4_4_2.npz'):
        my_file = filepath+filename
        d = np.load(my_file)
        time_diff1_00 = np.concatenate((time_diff1_00, d['time_diff1'][0][0]))
        time_diff1_01 = np.concatenate((time_diff1_01, d['time_diff1'][0][1]))
        time_diff1_02 = np.concatenate((time_diff1_02, d['time_diff1'][0][2]))
        time_diff1_03 = np.concatenate((time_diff1_03, d['time_diff1'][0][3]))
        time_diff1_04 = np.concatenate((time_diff1_04, d['time_diff1'][0][4]))
        time_diff1_05 = np.concatenate((time_diff1_05, d['time_diff1'][0][5]))
        time_diff1_10 = np.concatenate((time_diff1_10, d['time_diff1'][1][0]))
        time_diff1_11 = np.concatenate((time_diff1_11, d['time_diff1'][1][1]))
        time_diff1_12 = np.concatenate((time_diff1_12, d['time_diff1'][1][2]))
        time_diff1_13 = np.concatenate((time_diff1_13, d['time_diff1'][1][3]))
        time_diff1_14 = np.concatenate((time_diff1_14, d['time_diff1'][1][4]))
        time_diff1_15 = np.concatenate((time_diff1_15, d['time_diff1'][1][5]))
        time_diff1_20 = np.concatenate((time_diff1_20, d['time_diff1'][2][0]))
        time_diff1_21 = np.concatenate((time_diff1_21, d['time_diff1'][2][1]))
        time_diff1_22 = np.concatenate((time_diff1_22, d['time_diff1'][2][2]))
        time_diff1_23 = np.concatenate((time_diff1_23, d['time_diff1'][2][3]))
        time_diff1_24 = np.concatenate((time_diff1_24, d['time_diff1'][2][4]))
        time_diff1_25 = np.concatenate((time_diff1_25, d['time_diff1'][2][5]))
        time_diff1_30 = np.concatenate((time_diff1_30, d['time_diff1'][3][0]))
        time_diff1_31 = np.concatenate((time_diff1_31, d['time_diff1'][3][1]))
        time_diff1_32 = np.concatenate((time_diff1_32, d['time_diff1'][3][2]))
        time_diff1_33 = np.concatenate((time_diff1_33, d['time_diff1'][3][3]))
        time_diff1_34 = np.concatenate((time_diff1_34, d['time_diff1'][3][4]))
        time_diff1_35 = np.concatenate((time_diff1_35, d['time_diff1'][3][5]))
        time_diff1_40 = np.concatenate((time_diff1_40, d['time_diff1'][4][0]))
        time_diff1_41 = np.concatenate((time_diff1_41, d['time_diff1'][4][1]))
        time_diff1_42 = np.concatenate((time_diff1_42, d['time_diff1'][4][2]))
        time_diff1_43 = np.concatenate((time_diff1_43, d['time_diff1'][4][3]))
        time_diff1_44 = np.concatenate((time_diff1_44, d['time_diff1'][4][4]))
        time_diff1_45 = np.concatenate((time_diff1_45, d['time_diff1'][4][5]))
        time_diff1_50 = np.concatenate((time_diff1_50, d['time_diff1'][5][0]))
        time_diff1_51 = np.concatenate((time_diff1_51, d['time_diff1'][5][1]))
        time_diff1_52 = np.concatenate((time_diff1_52, d['time_diff1'][5][2]))
        time_diff1_53 = np.concatenate((time_diff1_53, d['time_diff1'][5][3]))
        time_diff1_54 = np.concatenate((time_diff1_54, d['time_diff1'][5][4]))
        time_diff1_55 = np.concatenate((time_diff1_55, d['time_diff1'][5][5]))
        time_diff1_60 = np.concatenate((time_diff1_60, d['time_diff1'][6][0]))
        time_diff1_61 = np.concatenate((time_diff1_61, d['time_diff1'][6][1]))
        time_diff1_62 = np.concatenate((time_diff1_62, d['time_diff1'][6][2]))
        time_diff1_63 = np.concatenate((time_diff1_63, d['time_diff1'][6][3]))
        time_diff1_64 = np.concatenate((time_diff1_64, d['time_diff1'][6][4]))
        time_diff1_65 = np.concatenate((time_diff1_65, d['time_diff1'][6][5]))
        time_diff1_70 = np.concatenate((time_diff1_70, d['time_diff1'][7][0]))
        time_diff1_71 = np.concatenate((time_diff1_71, d['time_diff1'][7][1]))
        time_diff1_72 = np.concatenate((time_diff1_72, d['time_diff1'][7][2]))
        time_diff1_73 = np.concatenate((time_diff1_73, d['time_diff1'][7][3]))
        time_diff1_74 = np.concatenate((time_diff1_74, d['time_diff1'][7][4]))
        time_diff1_75 = np.concatenate((time_diff1_75, d['time_diff1'][7][5]))
        time_diff1_80 = np.concatenate((time_diff1_80, d['time_diff1'][8][0]))
        time_diff1_81 = np.concatenate((time_diff1_81, d['time_diff1'][8][1]))
        time_diff1_82 = np.concatenate((time_diff1_82, d['time_diff1'][8][2]))
        time_diff1_83 = np.concatenate((time_diff1_83, d['time_diff1'][8][3]))
        time_diff1_84 = np.concatenate((time_diff1_84, d['time_diff1'][8][4]))
        time_diff1_85 = np.concatenate((time_diff1_85, d['time_diff1'][8][5]))
        
        time_diff2_00 = np.concatenate((time_diff2_00, d['time_diff2'][0][0]))
        time_diff2_01 = np.concatenate((time_diff2_01, d['time_diff2'][0][1]))
        time_diff2_02 = np.concatenate((time_diff2_02, d['time_diff2'][0][2]))
        time_diff2_03 = np.concatenate((time_diff2_03, d['time_diff2'][0][3]))
        time_diff2_04 = np.concatenate((time_diff2_04, d['time_diff2'][0][4]))
        time_diff2_05 = np.concatenate((time_diff2_05, d['time_diff2'][0][5]))
        time_diff2_10 = np.concatenate((time_diff2_10, d['time_diff2'][1][0]))
        time_diff2_11 = np.concatenate((time_diff2_11, d['time_diff2'][1][1]))
        time_diff2_12 = np.concatenate((time_diff2_12, d['time_diff2'][1][2]))
        time_diff2_13 = np.concatenate((time_diff2_13, d['time_diff2'][1][3]))
        time_diff2_14 = np.concatenate((time_diff2_14, d['time_diff2'][1][4]))
        time_diff2_15 = np.concatenate((time_diff2_15, d['time_diff2'][1][5]))
        time_diff2_20 = np.concatenate((time_diff2_20, d['time_diff2'][2][0]))
        time_diff2_21 = np.concatenate((time_diff2_21, d['time_diff2'][2][1]))
        time_diff2_22 = np.concatenate((time_diff2_22, d['time_diff2'][2][2]))
        time_diff2_23 = np.concatenate((time_diff2_23, d['time_diff2'][2][3]))
        time_diff2_24 = np.concatenate((time_diff2_24, d['time_diff2'][2][4]))
        time_diff2_25 = np.concatenate((time_diff2_25, d['time_diff2'][2][5]))
        time_diff2_30 = np.concatenate((time_diff2_30, d['time_diff2'][3][0]))
        time_diff2_31 = np.concatenate((time_diff2_31, d['time_diff2'][3][1]))
        time_diff2_32 = np.concatenate((time_diff2_32, d['time_diff2'][3][2]))
        time_diff2_33 = np.concatenate((time_diff2_33, d['time_diff2'][3][3]))
        time_diff2_34 = np.concatenate((time_diff2_34, d['time_diff2'][3][4]))
        time_diff2_35 = np.concatenate((time_diff2_35, d['time_diff2'][3][5]))
        time_diff2_40 = np.concatenate((time_diff2_40, d['time_diff2'][4][0]))
        time_diff2_41 = np.concatenate((time_diff2_41, d['time_diff2'][4][1]))
        time_diff2_42 = np.concatenate((time_diff2_42, d['time_diff2'][4][2]))
        time_diff2_43 = np.concatenate((time_diff2_43, d['time_diff2'][4][3]))
        time_diff2_44 = np.concatenate((time_diff2_44, d['time_diff2'][4][4]))
        time_diff2_45 = np.concatenate((time_diff2_45, d['time_diff2'][4][5]))
        time_diff2_50 = np.concatenate((time_diff2_50, d['time_diff2'][5][0]))
        time_diff2_51 = np.concatenate((time_diff2_51, d['time_diff2'][5][1]))
        time_diff2_52 = np.concatenate((time_diff2_52, d['time_diff2'][5][2]))
        time_diff2_53 = np.concatenate((time_diff2_53, d['time_diff2'][5][3]))
        time_diff2_54 = np.concatenate((time_diff2_54, d['time_diff2'][5][4]))
        time_diff2_55 = np.concatenate((time_diff2_55, d['time_diff2'][5][5]))
        time_diff2_60 = np.concatenate((time_diff2_60, d['time_diff2'][6][0]))
        time_diff2_61 = np.concatenate((time_diff2_61, d['time_diff2'][6][1]))
        time_diff2_62 = np.concatenate((time_diff2_62, d['time_diff2'][6][2]))
        time_diff2_63 = np.concatenate((time_diff2_63, d['time_diff2'][6][3]))
        time_diff2_64 = np.concatenate((time_diff2_64, d['time_diff2'][6][4]))
        time_diff2_65 = np.concatenate((time_diff2_65, d['time_diff2'][6][5]))
        time_diff2_70 = np.concatenate((time_diff2_70, d['time_diff2'][7][0]))
        time_diff2_71 = np.concatenate((time_diff2_71, d['time_diff2'][7][1]))
        time_diff2_72 = np.concatenate((time_diff2_72, d['time_diff2'][7][2]))
        time_diff2_73 = np.concatenate((time_diff2_73, d['time_diff2'][7][3]))
        time_diff2_74 = np.concatenate((time_diff2_74, d['time_diff2'][7][4]))
        time_diff2_75 = np.concatenate((time_diff2_75, d['time_diff2'][7][5]))
        time_diff2_80 = np.concatenate((time_diff2_80, d['time_diff2'][8][0]))
        time_diff2_81 = np.concatenate((time_diff2_81, d['time_diff2'][8][1]))
        time_diff2_82 = np.concatenate((time_diff2_82, d['time_diff2'][8][2]))
        time_diff2_83 = np.concatenate((time_diff2_83, d['time_diff2'][8][3]))
        time_diff2_84 = np.concatenate((time_diff2_84, d['time_diff2'][8][4]))
        time_diff2_85 = np.concatenate((time_diff2_85, d['time_diff2'][8][5]))

# %%
len(time_diff2_00)
# Out:
# 87831

# %%
plt.rcParams["font.size"]      = 15
plt.rcParams["figure.figsize"] = 10, 7.5
plt.hist(time_diff2_80, 100, (-500,500))
plt.show()

# %%
from   scipy           .stats               import norm
import invisible_cities.core .fit_functions as     fitf

y, x, _   = plt.hist(time_diff2_85, 100, (-1500, 1500))

mu, sigma = norm.fit(time_diff2_85)
f         = fitf.fit(fitf.gauss, x[:-1], y, (50, mu, sigma), fit_range=(-400, 400))
fwhm      = 2.35482 * (np.sqrt(np.var(time_diff2_85)))

mu2        = f.values[1]
mu2_err    = f.errors[1]
sigma2     = f.values[2]
sigma2_err = f.errors[2]
fwhm2      = sigma2    * 2.355
fwhm2_err  = sigma2_err* 2.355
chi2       = f.chi2

plt.plot(x, fitf.gauss(x, *f.values[ :3]), "r--", 
         label='$\mu$ = %.3f ± %.3f ps \n$\sigma$ = %.3f ± %.3f ps \nFWHM res = %.3f ± %.3f ps'% 
         (mu2, mu2_err, sigma2, sigma2_err, fwhm2, fwhm2_err))
plt.title (f"CTR (num init pes = 2, charge threshold = 0)", fontsize=18)
plt.ylabel(            'Entries/bin', fontsize=16)
plt.xlabel('CTR (ps)', fontsize=16)
plt.tick_params(labelsize=14)
plt.legend(fontsize=12, loc=1)

plt.tight_layout()

print('res time_diff2_85 = %.3f ± %.3f ps'%(fwhm2, fwhm2_err))
print('chi2', chi2/len(time_diff2_85))
# Out:
# res time_diff2_85 = 657.132 ± 7.555 ps
# chi2 0.05489321247342587

# %%
t_thr   = [0, 0.5, 1.0, 1.5, 2.0, 2.5]
num_of_init_pes = [1, 2, 3, 5, 8, 10, 12, 14, 16]

fwhm1_1sipm     = np.array([138.234, 143.246, 205.754, 232.519, 367.841, 398.636])
fwhm1_1sipm_err = np.array([5.425, 4.944, 7.449, 6.376, 7.680, 10.125])

fwhm1_2sipm     = np.array([129.904, 132.427, 219.556, 234.267, 398.985, 420.689])
fwhm1_2sipm_err = np.array([0.811, 0.644, 1.759, 1.824, 9.206, 11.693])

fwhm1_3sipm     = np.array([123.197, 125.779, 228.799, 240.117, 442.973, 461.028])
fwhm1_3sipm_err = np.array([0.401, 0.549, 1.387, 1.291, 6.382, 6.091])

fwhm1_5sipm     = np.array([115.719, 117.909, 226.179, 249.191, 495.804, 507.082])
fwhm1_5sipm_err = np.array([0.625, 0.619, 5.900, 2.085, 5.897, 5.483])

fwhm1_8sipm     = np.array([111.566, 113.187, 256.132, 264.704, 534.858, 543.169])
fwhm1_8sipm_err = np.array([0.787, 0.701, 2.224, 1.865, 8.203, 8.613])

fwhm1_10sipm     = np.array([110.723, 111.731, 264.032, 274.172, 558.200, 575.073])
fwhm1_10sipm_err = np.array([0.930, 0.875, 2.486, 2.134, 8.504, 7.662])

fwhm1_12sipm     = np.array([110.868, 111.618, 272.992, 283.294, 591.465, 602.576])
fwhm1_12sipm_err = np.array([1.048, 1.019, 2.993, 2.615, 6.661, 7.184])

fwhm1_14sipm     = np.array([112.573, 113.182, 286.688, 292.673, 615.807, 626.261])
fwhm1_14sipm_err = np.array([1.259, 1.246, 3.015, 3.219, 7.468, 7.864])

fwhm1_16sipm     = np.array([114.588, 114.969, 293.558, 296.333, 626.245, 637.645])
fwhm1_16sipm_err = np.array([1.378, 1.395, 2.905, 2.835, 8.885, 8.230])

# %%
plt.rcParams["font.size"]      = 12
plt.rcParams["figure.figsize"] = 12, 10
plt.errorbar(t_thr, fwhm1_1sipm,  fwhm1_1sipm_err,  marker='.', linestyle='-', c='r',       label=' 1 SiPM        ')
plt.errorbar(t_thr, fwhm1_2sipm,  fwhm1_2sipm_err,  marker='.', linestyle='-', c='k',       label=' 2 SiPM average')
plt.errorbar(t_thr, fwhm1_3sipm,  fwhm1_3sipm_err,  marker='.', linestyle='-', c='b',       label=' 3 SiPM average')
plt.errorbar(t_thr, fwhm1_5sipm,  fwhm1_5sipm_err,  marker='.', linestyle='-', c='g',       label=' 5 SiPM average')
plt.errorbar(t_thr, fwhm1_8sipm,  fwhm1_8sipm_err,  marker='.', linestyle='-', c='m',       label=' 8 SiPM average')
plt.errorbar(t_thr, fwhm1_10sipm, fwhm1_10sipm_err, marker='.', linestyle='-', c='y',       label='10 SiPM average')
plt.errorbar(t_thr, fwhm1_12sipm, fwhm1_12sipm_err, marker='.', linestyle='-', c='salmon',  label='12 SiPM average')
plt.errorbar(t_thr, fwhm1_14sipm, fwhm1_14sipm_err, marker='.', linestyle='-', c='skyblue', label='14 SiPM average')
plt.errorbar(t_thr, fwhm1_16sipm, fwhm1_16sipm_err, marker='.', linestyle='-', c='grey',    label='16 SiPM average')

#plt.errorbar(t_thr, fwhm2_1sipm,  fwhm2_1sipm_err,  marker='.', linestyle=':',  c='r',       label=' 1 SiPM         ')
plt.errorbar(t_thr, fwhm2_2sipm,  fwhm2_2sipm_err,  marker='.', linestyle=':',  c='k',       label=' 2 SiPM weig ave')
plt.errorbar(t_thr, fwhm2_3sipm,  fwhm2_3sipm_err,  marker='.', linestyle=':',  c='b',       label=' 3 SiPM weig ave')
plt.errorbar(t_thr, fwhm2_5sipm,  fwhm2_5sipm_err,  marker='.', linestyle=':',  c='g',       label=' 5 SiPM weig ave')
plt.errorbar(t_thr, fwhm2_8sipm,  fwhm2_8sipm_err,  marker='.', linestyle=':',  c='m',       label=' 8 SiPM weig ave')
plt.errorbar(t_thr, fwhm2_10sipm, fwhm2_10sipm_err, marker='.', linestyle=':',  c='y',       label='10 SiPM weig ave')
plt.errorbar(t_thr, fwhm2_12sipm, fwhm2_12sipm_err, marker='.', linestyle=':',  c='salmon',  label='12 SiPM weig ave')
plt.errorbar(t_thr, fwhm2_14sipm, fwhm2_14sipm_err, marker='.', linestyle=':',  c='skyblue', label='14 SiPM weig ave')
plt.errorbar(t_thr, fwhm2_16sipm, fwhm2_16sipm_err, marker='.', linestyle=':',  c='grey',    label='16 SiPM weig ave')

plt.ylim(50,700)
plt.title('Time of flight vs threshold', fontsize=16)
plt.xlabel('Threshold in charge (pes)', fontsize=14)
plt.ylabel('TOF (ps-FWHM)', fontsize=14)
plt.legend()
plt.show()

# %%
plt.rcParams["font.size"]      = 12
plt.rcParams["figure.figsize"] = 12, 10
plt.errorbar(t_thr, fwhm1_1sipm,  fwhm1_1sipm_err,  marker='.', linestyle='-', c='r',       label=' 1 SiPM        ')
plt.errorbar(t_thr, fwhm1_2sipm,  fwhm1_2sipm_err,  marker='.', linestyle='-', c='k',       label=' 2 SiPM average')
plt.errorbar(t_thr, fwhm1_3sipm,  fwhm1_3sipm_err,  marker='.', linestyle='-', c='b',       label=' 3 SiPM average')
plt.errorbar(t_thr, fwhm1_5sipm,  fwhm1_5sipm_err,  marker='.', linestyle='-', c='g',       label=' 5 SiPM average')
plt.errorbar(t_thr, fwhm1_8sipm,  fwhm1_8sipm_err,  marker='.', linestyle='-', c='m',       label=' 8 SiPM average')
plt.errorbar(t_thr, fwhm1_10sipm, fwhm1_10sipm_err, marker='.', linestyle='-', c='y',       label='10 SiPM average')
plt.errorbar(t_thr, fwhm1_12sipm, fwhm1_12sipm_err, marker='.', linestyle='-', c='salmon',  label='12 SiPM average')
plt.errorbar(t_thr, fwhm1_14sipm, fwhm1_14sipm_err, marker='.', linestyle='-', c='skyblue', label='14 SiPM average')
plt.errorbar(t_thr, fwhm1_16sipm, fwhm1_16sipm_err, marker='.', linestyle='-', c='grey',    label='16 SiPM average')

plt.ylim(50,700)
plt.title('Time of flight vs threshold (average of SiPMs)', fontsize=16)
plt.xlabel('Threshold in charge (pes)', fontsize=14)
plt.ylabel('TOF (ps-FWHM)', fontsize=14)
plt.legend()
plt.show()

# %%
plt.rcParams["font.size"]      = 12
plt.rcParams["figure.figsize"] = 12, 10
plt.errorbar(t_thr, fwhm2_1sipm,  fwhm2_1sipm_err,  marker='.', linestyle='-.', c='r',       label=' 1 SiPM        ')
plt.errorbar(t_thr, fwhm2_2sipm,  fwhm2_2sipm_err,  marker='.', linestyle='-.', c='k',       label=' 2 SiPM weig ave')
plt.errorbar(t_thr, fwhm2_3sipm,  fwhm2_3sipm_err,  marker='.', linestyle='-.', c='b',       label=' 3 SiPM weig ave')
plt.errorbar(t_thr, fwhm2_5sipm,  fwhm2_5sipm_err,  marker='.', linestyle='-.', c='g',       label=' 5 SiPM weig ave')
plt.errorbar(t_thr, fwhm2_8sipm,  fwhm2_8sipm_err,  marker='.', linestyle='-.', c='m',       label=' 8 SiPM weig ave')
plt.errorbar(t_thr, fwhm2_10sipm, fwhm2_10sipm_err, marker='.', linestyle='-.', c='y',       label='10 SiPM weig ave')
plt.errorbar(t_thr, fwhm2_12sipm, fwhm2_12sipm_err, marker='.', linestyle='-.', c='salmon',  label='12 SiPM weig ave')
plt.errorbar(t_thr, fwhm2_14sipm, fwhm2_14sipm_err, marker='.', linestyle='-.', c='skyblue', label='14 SiPM weig ave')
plt.errorbar(t_thr, fwhm2_16sipm, fwhm2_16sipm_err, marker='.', linestyle='-.', c='grey',    label='16 SiPM weig ave')

plt.ylim(50,700)
plt.title('Time of flight vs threshold (weighted average of SiPMs)', fontsize=16)
plt.xlabel('Threshold in charge (pes)', fontsize=14)
plt.ylabel('TOF (ps-FWHM)', fontsize=14)
plt.legend()
plt.show()

# %%
fwhm2_1sipm     = np.array([141.050, 142.562, 214.152, 234.617, 372.064, 406.807])
fwhm2_1sipm_err = np.array([1.457, 1.859, 1.268, 1.957, 5.014, 5.071])

fwhm2_2sipm     = np.array([133.239, 136.314, 222.799, 239.944, 412.633, 442.286])
fwhm2_2sipm_err = np.array([0.822, 0.603, 3.076, 4.459, 6.054, 7.055])

fwhm2_3sipm     = np.array([127.364, 130.199, 233.630, 250.457, 434.258, 456.771])
fwhm2_3sipm_err = np.array([0.728, 0.705, 4.346, 4.502, 5.779, 5.399])

fwhm2_5sipm     = np.array([120.477, 123.202, 243.512, 258.678, 492.890, 521.784])
fwhm2_5sipm_err = np.array([0.537, 0.605, 3.669, 1.988, 5.600, 4.687])

fwhm2_8sipm     = np.array([116.478, 118.161, 257.401, 270.987, 553.061, 562.621])
fwhm2_8sipm_err = np.array([0.591, 0.531, 6.104, 3.657, 6.834, 7.332])

fwhm2_10sipm     = np.array([115.519, 116.977, 265.151, 277.566, 582.281, 590.297])
fwhm2_10sipm_err = np.array([0.521, 0.506, 3.837, 2.327, 6.628, 7.775])

fwhm2_12sipm     = np.array([116.079, 117.009, 282.007, 286.330, 607.320, 616.440])
fwhm2_12sipm_err = np.array([0.701, 0.708, 2.422, 2.399, 7.611, 7.396])

fwhm2_14sipm     = np.array([117.131, 117.964, 291.690, 300.835, 628.634, 639.093])
fwhm2_14sipm_err = np.array([0.938, 0.916, 3.242, 2.313, 8.264, 8.634])

fwhm2_16sipm     = np.array([118.491, 119.147, 299.686, 308.302, 645.836, 657.132])
fwhm2_16sipm_err = np.array([0.692, 0.741, 2.922, 1.994, 7.212, 7.555])

# %%
diff0 = fwhm2_1sipm  - fwhm1_1sipm
diff1 = fwhm2_2sipm  - fwhm1_2sipm
diff2 = fwhm2_3sipm  - fwhm1_3sipm
diff3 = fwhm2_5sipm  - fwhm1_5sipm
diff4 = fwhm2_8sipm  - fwhm1_8sipm
diff5 = fwhm2_10sipm - fwhm1_10sipm
diff6 = fwhm2_12sipm - fwhm1_12sipm
diff7 = fwhm2_14sipm - fwhm1_14sipm
diff8 = fwhm2_16sipm - fwhm1_16sipm
diffs = np.array([diff0, diff1, diff2, diff3, diff4, diff5, diff6, diff7, diff8]).flatten()

# %%
plt.rcParams["figure.figsize"] = 10, 8
plt.hist(diffs, 100, (-50, 50))
plt.title('Diff CTR weighted ave time - ave time')
plt.xlabel('Time (ps)')
plt.ylabel('Entries')
plt.show()

# %%
res time_diff1_00 = 138.234 ± 5.425 ps
res time_diff1_01 = 143.246 ± 4.944 ps
res time_diff1_02 = 205.754 ± 7.449 ps
res time_diff1_03 = 232.519 ± 6.376 ps
res time_diff1_04 = 367.841 ± 7.680 ps
res time_diff1_05 = 398.636 ± 10.125 ps

res time_diff1_10 = 129.904 ± 0.811 ps
res time_diff1_11 = 132.427 ± 0.644 ps
res time_diff1_12 = 219.556 ± 1.759 ps
res time_diff1_13 = 234.267 ± 1.824 ps
res time_diff1_14 = 398.985 ± 9.206 ps
res time_diff1_15 = 420.689 ± 11.693 ps

res time_diff1_20 = 123.197 ± 0.401 ps
res time_diff1_21 = 125.779 ± 0.549 ps
res time_diff1_22 = 228.799 ± 1.387 ps
res time_diff1_23 = 240.117 ± 1.291 ps
res time_diff1_24 = 442.973 ± 6.382 ps
res time_diff1_25 = 461.028 ± 6.091 ps

res time_diff1_30 = 115.719 ± 0.625 ps
res time_diff1_31 = 117.909 ± 0.619 ps
res time_diff1_32 = 226.179 ± 5.900 ps
res time_diff1_33 = 249.191 ± 2.085 ps
res time_diff1_34 = 495.804 ± 5.897 ps
res time_diff1_35 = 507.082 ± 5.483 ps

res time_diff1_40 = 111.566 ± 0.787 ps
res time_diff1_41 = 113.187 ± 0.701 ps
res time_diff1_42 = 256.132 ± 2.224 ps
res time_diff1_43 = 264.704 ± 1.865 ps
res time_diff1_44 = 534.858 ± 8.203 ps
res time_diff1_45 = 543.169 ± 8.613 ps

res time_diff1_50 = 110.723 ± 0.930 ps
res time_diff1_51 = 111.731 ± 0.875 ps
res time_diff1_52 = 264.032 ± 2.486 ps
res time_diff1_53 = 274.172 ± 2.134 ps
res time_diff1_54 = 558.200 ± 8.504 ps
res time_diff1_55 = 575.073 ± 7.662 ps

res time_diff1_60 = 110.868 ± 1.048 ps
res time_diff1_61 = 111.618 ± 1.019 ps
res time_diff1_62 = 272.992 ± 2.993 ps
res time_diff1_63 = 283.294 ± 2.615 ps
res time_diff1_64 = 591.465 ± 6.661 ps
res time_diff1_65 = 602.576 ± 7.184 ps

res time_diff1_70 = 112.573 ± 1.259 ps
res time_diff1_71 = 113.182 ± 1.246 ps
res time_diff1_72 = 286.688 ± 3.015 ps
res time_diff1_73 = 292.673 ± 3.219 ps
res time_diff1_74 = 615.807 ± 7.468 ps
res time_diff1_75 = 626.261 ± 7.864 ps

res time_diff1_80 = 114.588 ± 1.378 ps
res time_diff1_81 = 114.969 ± 1.395 ps
res time_diff1_82 = 293.558 ± 2.905 ps
res time_diff1_83 = 296.333 ± 2.835 ps
res time_diff1_84 = 626.245 ± 8.885 ps
res time_diff1_85 = 637.645 ± 8.230 ps

# %%
res time_diff2_00 = 141.050 ± 1.457 ps
res time_diff2_01 = 142.562 ± 1.859 ps
res time_diff2_02 = 214.152 ± 1.268 ps
res time_diff2_03 = 234.617 ± 1.957 ps
res time_diff2_04 = 372.064 ± 5.014 ps
res time_diff2_05 = 406.807 ± 5.071 ps

res time_diff2_10 = 133.239 ± 0.822 ps
res time_diff2_11 = 136.314 ± 0.603 ps
res time_diff2_12 = 222.799 ± 3.076 ps
res time_diff2_13 = 239.944 ± 4.459 ps
res time_diff2_14 = 412.633 ± 6.054 ps
res time_diff2_15 = 442.286 ± 7.055 ps

res time_diff2_20 = 127.364 ± 0.728 ps
res time_diff2_21 = 130.199 ± 0.705 ps
res time_diff2_22 = 233.630 ± 4.346 ps
res time_diff2_23 = 250.457 ± 4.502 ps
res time_diff2_24 = 434.258 ± 5.779 ps
res time_diff2_25 = 456.771 ± 5.399 ps

res time_diff2_30 = 120.477 ± 0.537 ps
res time_diff2_31 = 123.202 ± 0.605 ps
res time_diff2_32 = 243.512 ± 3.669 ps
res time_diff2_33 = 258.678 ± 1.988 ps
res time_diff2_34 = 492.890 ± 5.600 ps
res time_diff2_35 = 521.784 ± 4.687 ps

res time_diff2_40 = 116.478 ± 0.591 ps
res time_diff2_41 = 118.161 ± 0.531 ps
res time_diff2_42 = 257.401 ± 6.104 ps
res time_diff2_43 = 270.987 ± 3.657 ps
res time_diff2_44 = 553.061 ± 6.834 ps
res time_diff2_45 = 562.621 ± 7.332 ps

res time_diff2_50 = 115.519 ± 0.521 ps
res time_diff2_51 = 116.977 ± 0.506 ps
res time_diff2_52 = 265.151 ± 3.837 ps
res time_diff2_53 = 277.566 ± 2.327 ps
res time_diff2_54 = 582.281 ± 6.628 ps
res time_diff2_55 = 590.297 ± 7.775 ps

res time_diff2_60 = 116.079 ± 0.701 ps
res time_diff2_61 = 117.009 ± 0.708 ps
res time_diff2_62 = 282.007 ± 2.422 ps
res time_diff2_63 = 286.330 ± 2.399 ps
res time_diff2_64 = 607.320 ± 7.611 ps
res time_diff2_65 = 616.440 ± 7.396 ps

res time_diff2_70 = 117.131 ± 0.938 ps
res time_diff2_71 = 117.964 ± 0.916 ps
res time_diff2_72 = 291.690 ± 3.242 ps
res time_diff2_73 = 300.835 ± 2.313 ps
res time_diff2_74 = 628.634 ± 8.264 ps
res time_diff2_75 = 639.093 ± 8.634 ps

res time_diff2_80 = 118.491 ± 0.692 ps
res time_diff2_81 = 119.147 ± 0.741 ps
res time_diff2_82 = 299.686 ± 2.922 ps
res time_diff2_83 = 308.302 ± 1.994 ps
res time_diff2_84 = 645.836 ± 7.212 ps
res time_diff2_85 = 657.132 ± 7.555 ps
