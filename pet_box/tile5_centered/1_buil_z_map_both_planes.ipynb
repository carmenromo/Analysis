# %%
import os
import numpy  as np
import tables as tb

import matplotlib.pyplot as plt

from   invisible_cities.core.core_functions import in_range
import invisible_cities.core.fit_functions  as fitf
from invisible_cities.core.core_functions import shift_to_bin_centers

from   invisible_cities.reco import tbl_functions as tbl

# %%
plt.rcParams["font.size"] = 15

# %%
evts_path = '/Users/carmenromoluque/nexus_petit_analysis/tof_setup/PetBox_analysis/data_z_map/both_planes_Ham/'

thr_ch_start  = 0
thr_ch_nsteps = 6

true_z1_all = [[] for i in range(thr_ch_start, thr_ch_nsteps)]
var_x1_all  = [[] for i in range(thr_ch_start, thr_ch_nsteps)]
charge1_all = [[] for i in range(thr_ch_start, thr_ch_nsteps)]
evts1_all   = [[] for i in range(thr_ch_start, thr_ch_nsteps)]

true_z1 = [[] for i in range(thr_ch_start, thr_ch_nsteps)]
var_x1  = [[] for i in range(thr_ch_start, thr_ch_nsteps)]
charge1 = [[] for i in range(thr_ch_start, thr_ch_nsteps)]
evts1   = [[] for i in range(thr_ch_start, thr_ch_nsteps)]

true_z2_all = [[] for i in range(thr_ch_start, thr_ch_nsteps)]
var_x2_all  = [[] for i in range(thr_ch_start, thr_ch_nsteps)]
charge2_all = [[] for i in range(thr_ch_start, thr_ch_nsteps)]
evts2_all   = [[] for i in range(thr_ch_start, thr_ch_nsteps)]

true_z2 = [[] for i in range(thr_ch_start, thr_ch_nsteps)]
var_x2  = [[] for i in range(thr_ch_start, thr_ch_nsteps)]
charge2 = [[] for i in range(thr_ch_start, thr_ch_nsteps)]
evts2   = [[] for i in range(thr_ch_start, thr_ch_nsteps)]

for filename in os.listdir(evts_path):
    if filename.endswith('.npz'):
        my_file = evts_path+filename        
        d = np.load(my_file, allow_pickle=True)
        for j in range(thr_ch_start, thr_ch_nsteps):
            for i in d[f'true_z1_all_{j}']:
                true_z1_all[j].append(i)
            for i in d[f'var_x1_all_{j}']:
                var_x1_all[j].append(i)
            for i in d[f'charge1_all_{j}']:
                charge1_all[j].append(i)
            for i in d[f'evts1_all_{j}']:
                evts1_all[j].append(i)
            for i in d[f'true_z1_{j}']:
                true_z1[j].append(i)
            for i in d[f'var_x1_{j}']:
                var_x1[j].append(i)
            for i in d[f'charge1_{j}']:
                charge1[j].append(i)
            for i in d[f'evts1_{j}']:
                evts1[j].append(i)
            for i in d[f'true_z2_all_{j}']:
                true_z2_all[j].append(i)
            for i in d[f'var_x2_all_{j}']:
                var_x2_all[j].append(i)
            for i in d[f'charge2_all_{j}']:
                charge2_all[j].append(i)
            for i in d[f'evts2_all_{j}']:
                evts2_all[j].append(i)
            for i in d[f'true_z2_{j}']:
                true_z2[j].append(i)
            for i in d[f'var_x2_{j}']:
                var_x2[j].append(i)
            for i in d[f'charge2_{j}']:
                charge2[j].append(i)
            for i in d[f'evts2_{j}']:
                evts2[j].append(i)
            
true_z1_all_a = np.array([np.array(i) for i in true_z1_all])
var_x1_all_a  = np.array([np.array(i) for i in var_x1_all ])
charge1_all_a = np.array([np.array(i) for i in charge1_all])
evts1_all_a   = np.array([np.array(i) for i in evts1_all  ])
true_z1_a     = np.array([np.array(i) for i in true_z1    ])
var_x1_a      = np.array([np.array(i) for i in var_x1     ])
charge1_a     = np.array([np.array(i) for i in charge1    ])
evts1_a       = np.array([np.array(i) for i in evts1      ])
true_z2_all_a = np.array([np.array(i) for i in true_z2_all])
var_x2_all_a  = np.array([np.array(i) for i in var_x2_all ])
charge2_all_a = np.array([np.array(i) for i in charge2_all])
evts2_all_a   = np.array([np.array(i) for i in evts2_all  ])
true_z2_a     = np.array([np.array(i) for i in true_z2    ])
var_x2_a      = np.array([np.array(i) for i in var_x2     ])
charge2_a     = np.array([np.array(i) for i in charge2    ])
evts2_a       = np.array([np.array(i) for i in evts2      ])

# %%
plt.rcParams["figure.figsize"] = 10, 6
for i in range(thr_ch_start, thr_ch_nsteps):
    plt.hist(charge1_all_a[i], 150, (0, 4000), alpha=0.6)
plt.show()
for i in range(thr_ch_start, thr_ch_nsteps):
    plt.hist(charge1_a[i], 150, (0, 4000), alpha=0.6)
    plt.axvline(x=1400, c='g')
plt.show()
for i in range(thr_ch_start, thr_ch_nsteps):
    plt.hist(charge2_all_a[i], 150, (0, 4000), alpha=0.6)
plt.show()
for i in range(thr_ch_start, thr_ch_nsteps):
    plt.hist(charge2_a[i], 150, (0, 4000), alpha=0.6)
plt.show()

# %%
plt.rcParams["figure.figsize"] = 10, 6
plt.hist(charge1_all_a[2], 150, (0, 4000), alpha=0.6)
plt.show()
plt.hist(charge1_a[2], 150, (0, 4000), alpha=0.6)
plt.axvline(x=1400, c='g')
plt.show()
plt.hist(charge2_all_a[2], 150, (0, 4000), alpha=0.6)
plt.show()
plt.hist(charge2_a[2], 150, (0, 4000), alpha=0.6)
plt.show()

# %%
ch_val = 1400
sel = charge1_a[2] > ch_val
plt.hist(charge1_a[2][ sel], 150, (0, 4000), alpha=0.8, color='salmon', label=f'charge > {ch_val} pes')
plt.hist(charge1_a[2][~sel], 150, (0, 4000), alpha=0.8, color='teal',   label=f'charge < {ch_val} pes')
plt.axvline(x=1400, c='g')
plt.xlabel('Charge detector plane (pes)')
plt.ylabel('Entries')
plt.legend(fontsize=15)
plt.show()

# %%
ch_val = 1400
bins   = 100

def set_titles(ax, above=False, var=True):
    ax.set_ylabel('Z true (mm)')
    if var:
        ax.set_xlabel('Var X (mm)')
    else:
        ax.set_xlabel('Sigma X (mm)')
    if above:
        ax.set_title(f'Thr=2pes, Charges > {ch_val} pes')
    else:
        ax.set_title(f'Thr=2pes, Charges < {ch_val} pes')

for j in range(thr_ch_start, thr_ch_nsteps):
    if j==2:
        sel = charge1_a[j] > ch_val
        fig, (ax0, ax1) = plt.subplots(1,2,figsize=(14,4.5))
         
        fig0 = ax0.hist2d(var_x1_a[j][~sel], true_z1_a[j][~sel], bins=(bins, bins), cmin=1)
        fig1 = ax1.hist2d(var_x1_a[j][ sel], true_z1_a[j][ sel], bins=(bins, bins), cmin=1)
        ax1.axvline(x=210, c='g')
        
        set_titles(ax0, above=False, var=True)
        set_titles(ax1, above=True,  var=True)
    
        plt.tight_layout()
        plt.show()
        
        plt.rcParams["figure.figsize"] = 8, 4.5
        plt.scatter(var_x1_a[j][~sel], true_z1_a[j][~sel], s=2, label=f'charge<{ch_val}keV', alpha=0.4)
        plt.scatter(var_x1_a[j][ sel], true_z1_a[j][ sel], s=2, label=f'charge>{ch_val}keV', alpha=0.4)
        plt.xlabel('Var X (mm)')
        plt.ylabel('Z true (mm)')
        plt.legend()
        plt.tight_layout()
        plt.show()
        
for j in range(thr_ch_start, thr_ch_nsteps):
    if j==2:
        sel = charge1_a[j] > ch_val
        fig, (ax0, ax1) = plt.subplots(1,2,figsize=(14,4.5))
        fig0 = ax0.hist2d(np.sqrt(var_x1_a[j][~sel]), true_z1_a[j][~sel], bins=(bins, bins), cmin=1)
        fig1 = ax1.hist2d(np.sqrt(var_x1_a[j][ sel]), true_z1_a[j][ sel], bins=(bins, bins), cmin=1)
        ax1.axvline(x=210, c='g')
        
        set_titles(ax0, above=False, var=False)
        set_titles(ax1, above=True , var=False)
    
        plt.tight_layout()
        plt.show()
        
        plt.rcParams["figure.figsize"] = 8, 4.5
        plt.scatter(np.sqrt(var_x1_a[j][~sel]), true_z1_a[j][~sel], s=2, label=f'charge<{ch_val}keV', alpha=0.4)
        plt.scatter(np.sqrt(var_x1_a[j][ sel]), true_z1_a[j][ sel], s=2, label=f'charge>{ch_val}keV', alpha=0.4)
        plt.xlabel('Sigma X (mm)')
        plt.ylabel('Z true (mm)')
        plt.legend()
        plt.tight_layout()
        plt.show()

# %%
bins   = 100

#for j in range(thr_ch_start, thr_ch_nsteps):
plt.rcParams["figure.figsize"] = 8, 4.5
plt.hist2d(var_x1_all_a[2], true_z1_all_a[2], bins=(bins, bins), cmin=1)
plt.xlabel('Var X (mm)')
plt.ylabel('Z true (mm)')
plt.colorbar().set_label("Number of events")
plt.tight_layout()
plt.show()

#for j in range(thr_ch_start, thr_ch_nsteps):
plt.rcParams["figure.figsize"] = 8, 4.5
plt.hist2d(np.sqrt(var_x1_all_a[2]), true_z1_all_a[2], bins=(bins, bins), cmin=1)
plt.xlabel('Var X (mm)')
plt.ylabel('Z true (mm)')
plt.colorbar().set_label("Number of events")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Coincidence plane

# %%
bins   = 100

#for j in range(thr_ch_start, thr_ch_nsteps):
plt.rcParams["figure.figsize"] = 8, 4.5
plt.hist2d(var_x2_a[2], true_z2_a[2], bins=(bins, bins), cmin=1)
plt.xlabel('Var X (mm)')
plt.ylabel('Z true (mm)')
plt.colorbar().set_label("Number of events")
plt.tight_layout()
plt.show()

#for j in range(thr_ch_start, thr_ch_nsteps):
plt.rcParams["figure.figsize"] = 8, 4.5
plt.hist2d(np.sqrt(var_x2_a[2]), true_z2_a[2], bins=(bins, bins), cmin=1)
plt.xlabel('Var X (mm)')
plt.ylabel('Z true (mm)')
plt.colorbar().set_label("Number of events")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Det and Coinc planes together:

# %%
plt.rcParams["figure.figsize"] = 8, 6
plt.scatter(var_x1_a[j],  true_z1_a[j], s=2, label=f'Det plane',   alpha=0.4)
plt.scatter(var_x2_a[j], -true_z2_a[j], s=2, label=f'Coinc plane', alpha=0.4)
plt.xlabel('Var X (mm)')
plt.ylabel('Z true (mm)')
plt.legend()

## Change colors in legend
t1, t2 = plt.legend().get_texts()
t1.set_color("C0")
t2.set_color("C1")

# %% [markdown]
# ## Profile:

# %% [markdown]
# ## Var X

# %% [markdown]
# ### detector plane

# %%
z_lim, varx_lim = (-54.1, -35.), (0, 210)
Zbins, Vbins = 100, 100

thr  = 2
sel2 = in_range(var_x1_a[thr][sel], *varx_lim) & in_range(true_z1_a[thr][sel], *z_lim)
v, z = var_x1_a[thr][sel][sel2], true_z1_a[thr][sel][sel2]

plt.rcParams["figure.figsize"] = 10, 6
plt.hist2d(v, z, (Vbins, Zbins), cmin=1)

x, y, yu = fitf.profileX(v, z, Zbins, xrange=varx_lim, yrange=z_lim, drop_nan=False)

plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)
plt.title('Var X')
plt.xlabel('Var X (mm)')
plt.ylabel('Z pos (mm)')
plt.colorbar().set_label("Number of events")
plt.show()

# %%
y1 = -54
x1 = -5
y2 = -37
x2 = 200
slope = (y2 - y1)/(x2 - x1)
xs = np.arange(0, 210)
print(slope)
line_test  = var_x1_a[thr][sel]*slope - 51
line_test2 = var_x1_a[thr][sel]*slope - 54.5
# Out:
# 0.08292682926829269

# %%
plt.rcParams["figure.figsize"] = 10, 6
plt.hist2d(v, z, (Vbins, Zbins), cmin=1)

x, y, yu = fitf.profileX(v, z, Zbins, xrange=varx_lim, yrange=z_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)
plt.title('Var X')
plt.xlabel('Var X (mm)')
plt.ylabel('Z pos (mm)')
plt.colorbar().set_label("Number of events")
#plt.show()
plt.plot(var_x1_a[thr][sel], line_test,  color='r', linestyle='--', linewidth=0.5)
plt.plot(var_x1_a[thr][sel], line_test2, color='r', linestyle='--', linewidth=0.5)
plt.show()

# %%
sel_lines = (true_z1_a[thr][sel] < (line_test)) & (true_z1_a[thr][sel] > (line_test2))
v, z      = var_x1_a[thr][sel][sel2&sel_lines], true_z1_a[thr][sel][sel2&sel_lines]

plt.hist2d(v, z, (Vbins, Zbins), cmin=1)

x, y, yu = fitf.profileX(v, z, Zbins, xrange=varx_lim, yrange=z_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)
plt.xlabel('Var X (mm)')
plt.ylabel('Z pos (mm)')
plt.colorbar().set_label("Number of events")
plt.plot(var_x1_a[thr][sel], line_test,  color='r', linestyle='--', linewidth=0.5)
plt.plot(var_x1_a[thr][sel], line_test2, color='r', linestyle='--', linewidth=0.5)
plt.show()

# %%
plt.hist2d(var_x1_a[thr][sel], true_z1_a[thr][sel], bins=(200, 200), cmin=1)

x, y, yu = fitf.profileX(v, z, Zbins, xrange=varx_lim, yrange=z_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)

plt.title(f'Thr=2pes, Charges > {ch_val} pes')
plt.xlabel('Var X (mm)')
plt.ylabel('Z pos (mm)')
plt.colorbar().set_label("Number of events")
plt.show()

# %%
plt.hist2d(var_x1_a[thr], true_z1_a[thr], bins=(200, 200), cmin=1)

x, y, yu = fitf.profileX(v, z, Zbins, xrange=varx_lim, yrange=z_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)

plt.title(f'Thr=2pes, All events')
plt.xlabel('Var X (mm)')
plt.ylabel('Z pos (mm)')
plt.colorbar().set_label("Number of events")
plt.show()

# %% [markdown]
# ### Store data for the table:

# %%
ZnBins   = [50, 100, 150, 200]
ZRange   = z_lim # = (-54.1, -35.)
ZBins    = {n: np.linspace(*ZRange, n + 1) for n       in ZnBins       }
ZCenters = {n: shift_to_bin_centers(bins)  for n, bins in ZBins.items()}
ZPitch   = {n: np.diff(bins)[0]            for n, bins in ZBins.items()}

# %%
thr  = 2
sel2      = in_range(var_x1_a[thr][sel], *varx_lim) & in_range(true_z1_a[thr][sel], *z_lim)
sel_lines = (true_z1_a[thr][sel] < (line_test)) & (true_z1_a[thr][sel] > (line_test2))
v, z      = var_x1_a[thr][sel][sel2&sel_lines], true_z1_a[thr][sel][sel2&sel_lines]

Var_X   = {}
Z_ave   = {}
Z_ave_u = {} # uncertainty
for n in ZnBins:
    x, y, yu = fitf.profileX(v, z, n, xrange=varx_lim, yrange=z_lim, drop_nan=False)
    Z_ave  [n] = y
    Z_ave_u[n] = yu
    Var_X  [n] = x
    #print(x, y, yu)
    #x, y, yu = fitf.profileY(v, z, n, xrange=varx_lim, yrange=z_lim, drop_nan=False)

# %% [markdown]
# ### Create table

# %%
path = '/Users/carmenromoluque/nexus_petit_analysis/tof_setup/PetBox_analysis/'
z_table_name = path+'z_var_x_table_pet_box_HamamatsuVUV_det_plane_coinc_plane_cent.h5'

class ZposT(tb.IsDescription):
    Var_x           = tb.Float32Col(pos=0)
    Zpos            = tb.Float32Col(pos=0)
    ZposUncertainty = tb.Float32Col(pos=0)

with tb.open_file(z_table_name, "w") as output_file:
    
    if '/Zpos' in output_file:
        Zpos = output_file.root.Zpos        
    else:
        Zpos = output_file.create_group(output_file.root, "Zpos")
    
    for n in ZBins:
        pitch      = ZPitch[n]
        table_name = f"f{thr}pes{n}bins"

        z_table = output_file.create_table(Zpos, table_name,
                               description = ZposT,
                               title       = "z_pos",
                               filters     = tbl.filters('ZLIB4'))
    
    
        for i, var in enumerate(ZCenters[n], start=0):
            row                    = z_table.row
            row["Var_x"]           = Var_X  [n][i]
            row["Zpos"]            = Z_ave  [n][i]
            row["ZposUncertainty"] = Z_ave_u[n][i] * Z_ave[n][i] / 100
            row.append()

        table = getattr(getattr(output_file.root, 'Zpos'), table_name)
        table.attrs.Z_bins  = n
        table.attrs.Z_pitch = pitch

# %% [markdown]
# ## Coincidence plane:

# %%
print(max(true_z2_a[thr]), min(true_z2_a[thr]))
# Out:
# 54.13594 27.051596

# %% [markdown]
# ### Option 1

# %%
z_lim, varx_lim = (27., 54.1), (0, 75)
Zbins, Vbins = 100, 100

thr  = 2
sel2 = in_range(true_z2_a[thr], *z_lim) & in_range(var_x2_a[thr], *varx_lim)
z, v = true_z2_a[thr][sel2], var_x2_a[thr][sel2]

plt.rcParams["figure.figsize"] = 10, 6
plt.hist2d(z, v, (Zbins, Vbins), cmin=1)

x, y, yu = fitf.profileX(z, v, Zbins, xrange=z_lim, yrange=varx_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)
plt.xlabel('Z pos (mm)')
plt.ylabel('Var X (mm)')
plt.colorbar().set_label("Number of events")
plt.show()

# %%
z_lim, varx_lim = (27., 54.1), (0, 75)
Zbins, Vbins = 200, 200

thr  = 2
sel2 = in_range(true_z2_a[thr][charge2_a[thr]>200], *z_lim) & in_range(var_x2_a[thr][charge2_a[thr]>200], *varx_lim)
z, v = true_z2_a[thr][charge2_a[thr]>200][sel2], var_x2_a[thr][charge2_a[thr]>200][sel2]

plt.rcParams["figure.figsize"] = 10, 6
plt.hist2d(z, v, (Zbins, Vbins), cmin=1)

x, y, yu = fitf.profileX(z, v, Zbins, xrange=z_lim, yrange=varx_lim, drop_nan=False)
#plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)
plt.title('Coinc plane charge > 200pes')
plt.xlabel('Z pos (mm)')
plt.ylabel('Var X (mm)')
plt.colorbar().set_label("Number of events")
plt.show()

# %%
sel2 = in_range(true_z2_a[thr], *z_lim) & in_range(var_x2_a[thr], *varx_lim)
z, v = true_z2_a[thr][sel2], var_x2_a[thr][sel2]

plt.rcParams["figure.figsize"] = 10, 6
plt.hist2d(z, v, (Zbins, Vbins), cmin=2)

x, y, yu = fitf.profileX(z, v, Zbins, z_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)
plt.title('Var X')
plt.xlabel('Z pos (mm)')
plt.ylabel('Var X (mm)')
plt.colorbar().set_label("Number of events")


#line  = (-0.13813199)*x*x + (9.34355559)*x -101.1623518#  + 0.8
line2 = (-0.13813199)*x*x + (9.34355559)*x -101.1623518  - 2
line3 = (-0.13813199)*x*x + (9.34355559)*x -101.1623518 + 11
line4 = (-0.15      )*x*x + (9.2       )*x -101.1623518 + 45
#plt.plot(x, line, color='r', linestyle='--', linewidth=2)
plt.plot(x, line2, color='r', linestyle='--', linewidth=2)
plt.plot(x, line3, color='r', linestyle='--', linewidth=2)
plt.plot(x, line4, color='r', linestyle='--', linewidth=2)
plt.show()

# %%
z_lim, varx_lim = (27., 54.1), (0, 75)
Zbins, Vbins = 100, 100

thr  = 2
sel2 = in_range(true_z2_a[thr], *z_lim) & in_range(var_x2_a[thr], *varx_lim)
z, v = true_z2_a[thr][sel2], var_x2_a[thr][sel2]

plt.rcParams["figure.figsize"] = 10, 6
plt.hist2d(z, v, (Zbins, Vbins), cmin=2)

x, y, yu = fitf.profileX(z, v, Zbins, z_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)
plt.title('Var X')
plt.xlabel('Z pos (mm)')
plt.ylabel('Var X (mm)')
plt.colorbar().set_label("Number of events")


#line  = (-0.13813199)*x*x + (9.34355559)*x -101.1623518#  + 0.8
line2 = (-0.13813199)*x*x + (9.34355559)*x -101.1623518  - 2
#line3 = (-0.13813199)*x*x + (9.34355559)*x -101.1623518 + 11
line4 = (-0.15      )*x*x + (9.2       )*x -101.1623518 + 46
#line5 = (-0.17)*x*x + (9.5)*x -101.1623518 + 11
line6 = (-0.16)*x*x + (9.7)*x -101.1623518 + 9
#plt.plot(x, line, color='r', linestyle='--', linewidth=2)
plt.plot(x, line2, color='r', linestyle='--', linewidth=2)
#plt.plot(x, line3, color='b', linestyle='--', linewidth=2)
plt.plot(x, line4, color='g', linestyle='--', linewidth=2)
#plt.plot(x, line5, color='yellow', linestyle='--', linewidth=2)
plt.plot(x, line6, color='orange', linestyle='--', linewidth=2)
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))

#z_lim, varx_lim = (38., 54.1), (0, 65)
z_lim, varx_lim = (27., 54.1), (0, 75)
Zbins, Vbins = 100, 100

plt.hist2d(true_z2_a[2], var_x2_a[2], bins=(200, 200), cmin=1)

thr  = 2
sel2 = in_range(true_z2_a[thr], *z_lim) & in_range(var_x2_a[thr], *varx_lim)

#lines  = ((var_x2_a[thr] > ((-0.13813199)*true_z2_a[thr]*true_z2_a[thr] + (9.34355559)*true_z2_a[thr] -101.1623518 - 2)) &
#          (var_x2_a[thr] < ((-0.13813199)*true_z2_a[thr]*true_z2_a[thr] + (9.34355559)*true_z2_a[thr] -101.1623518 + 11)) &
#          (var_x2_a[thr] < ((-0.15      )*true_z2_a[thr]*true_z2_a[thr] + (9.2       )*true_z2_a[thr] -101.1623518 + 45)))

lines  = ((var_x2_a[thr] > ((-0.13813199)*true_z2_a[thr]*true_z2_a[thr] + (9.34355559)*true_z2_a[thr] -101.1623518 -  2)) &
          (var_x2_a[thr] < ((-0.15      )*true_z2_a[thr]*true_z2_a[thr] + (9.2       )*true_z2_a[thr] -101.1623518 + 46)) &
          (var_x2_a[thr] > ((-0.16      )*true_z2_a[thr]*true_z2_a[thr] + (9.7       )*true_z2_a[thr] -101.1623518 +  9)))

#line2 = (-0.13813199)*x*x + (9.34355559)*x -101.1623518 - 2
#line4 = (-0.15      )*x*x + (9.2       )*x -101.1623518 + 46
#line6 = (-0.16      )*x*x + (9.7       )*x -101.1623518 + 9

z, v = true_z2_a[thr][sel2&lines], var_x2_a[thr][sel2&lines]

#plt.rcParams["figure.figsize"] = 10, 6
plt.hist2d(z, v, (Zbins, Vbins), cmin=1)

x, y, yu = fitf.profileX(z, v, Zbins, z_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)
plt.xlabel('Z pos (mm)', fontsize=16)
plt.ylabel('Var X (mm)', fontsize=16)
plt.colorbar().set_label("Number of events")
#fig.savefig(f"/Users/carmenromoluque/Desktop/z_map_coinc_plane.pdf")
plt.show()

# %%
z_lim, varx_lim = (27., 54.1), (0, 70)
plt.rcParams["figure.figsize"] = 10, 6
plt.hist2d(v, z, (Zbins, Vbins), cmin=1)

x, y, yu = fitf.profileX(v, z, Zbins, xrange=varx_lim, yrange=z_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)
plt.xlabel('Var X (mm)', fontsize=16)
plt.ylabel('Z pos (mm)', fontsize=16)
plt.colorbar().set_label("Number of events")
plt.show()

# %%
z, v = true_z2_a[thr][sel2&lines], var_x2_a[thr][sel2&lines]

plt.rcParams["figure.figsize"] = 10, 6
plt.hist2d(z, v, (Zbins, Vbins), cmin=1)

x, y, yu = fitf.profileX(z, v, Zbins, z_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)
plt.xlabel('Z pos (mm)', fontsize=16)
plt.ylabel('Var X (mm)', fontsize=16)
plt.colorbar().set_label("Number of events")
plt.show()

# %% [markdown]
# ## Store data for the table. Option1

# %%
ZnBins   = [50, 100, 150, 200]
ZRange   = (27.0, 54.1)
ZBins    = {n: np.linspace(*ZRange, n + 1) for n       in ZnBins}
ZCenters = {n: shift_to_bin_centers(bins)  for n, bins in ZBins.items()}
ZPitch   = {n: np.diff(bins)[0]            for n, bins in ZBins.items()}

# %%
thr  = 2
sel2 = in_range(true_z2_a[thr], *z_lim) & in_range(var_x2_a[thr], *varx_lim)
z, v = true_z2_a[thr][sel2&lines], var_x2_a[thr][sel2&lines]

VarX_ave   = {}
VarX_ave_u = {} # uncertainty
for n in ZnBins:
    x, y, yu = fitf.profileX(z, v, n, xrange=z_lim, yrange=varx_lim, drop_nan=False)
    VarX_ave  [n] = y
    VarX_ave_u[n] = yu
    print(x, y, yu)
# Out:
# [27.271 27.813 28.355 28.897 29.439 29.981 30.523 31.065 31.607 32.149
#  32.691 33.233 33.775 34.317 34.859 35.401 35.943 36.485 37.027 37.569
#  38.111 38.653 39.195 39.737 40.279 40.821 41.363 41.905 42.447 42.989
#  43.531 44.073 44.615 45.157 45.699 46.241 46.783 47.325 47.867 48.409
#  48.951 49.493 50.035 50.577 51.119 51.661 52.203 52.745 53.287 53.829] [63.62235906 63.50772652 63.37007389 63.29494931 63.17828818 63.01019107
#  62.90967789 62.71999752 62.53584132 62.33519411 62.16616519 61.91712274
#  61.6037027  61.27439219 61.05599511 61.02376185 60.35981278 60.18788041
#  59.70414926 59.06432846 58.57428402 58.43748792 57.73248054 57.01682294
#  56.55419019 55.72119467 55.022129   54.01250196 53.16308896 52.12934105
#  50.97244979 49.73812318 48.36772103 46.88640744 45.10986705 43.37953207
#  41.49707416 39.0923372  36.58001724 34.55425934 31.51501082 28.30101026
#  25.44186934 22.25540278 19.4205646  15.98015113 12.52801923  8.83510581
# ...

# %% [markdown]
# ## Create table

# %%
path = '/Users/carmenromoluque/nexus_petit_analysis/tof_setup/PetBox_analysis/'
VarX_table_name = path+'z_var_x_table_pet_box_HamamatsuVUV_coinc_plane_cent0.h5'

class ZposT(tb.IsDescription):
    Zpos            = tb.Float32Col(pos=0)
    Var_x           = tb.Float32Col(pos=0)
    VarXUncertainty = tb.Float32Col(pos=0)

with tb.open_file(VarX_table_name, "w") as output_file:
    
    if '/Zpos' in output_file:
        Zpos = output_file.root.Zpos        
    else:
        Zpos = output_file.create_group(output_file.root, "Zpos")
    
    for n in ZBins:
        pitch      = ZPitch[n]
        table_name = f"f{thr}pes{n}bins"

        z_table = output_file.create_table(Zpos, table_name,
                                           description = ZposT,
                                           title       = "z_pos",
                                           filters     = tbl.filters('ZLIB4'))
    
    
        for i, zs in enumerate(ZCenters[n], start=0):
            row                    = z_table.row
            row["Zpos"]            = zs
            row["Var_x"]           = VarX_ave  [n][i]
            row["VarXUncertainty"] = VarX_ave_u[n][i] * VarX_ave[n][i] / 100
            row.append()

        table = getattr(getattr(output_file.root, 'Zpos'), table_name)
        table.attrs.Z_bins  = n
        table.attrs.Z_pitch = pitch

# %% [markdown]
# ### tests option 1

# %%
### LINES TO choose the region

from scipy.optimize import curve_fit

z_lim, varx_lim = (27., 54.1), (0, 75)
Zbins, Vbins = 100, 100

thr  = 2
sel2 = in_range(true_z2_a[thr], *z_lim) & in_range(var_x2_a[thr], *varx_lim)
z, v = true_z2_a[thr][sel2], var_x2_a[thr][sel2]

plt.scatter(z, v, s=0.5)
x, y, yu = fitf.profileX(z, v, Zbins, z_lim, drop_nan=False)
#pfit = np.polyfit(x[6:], y[6:], 1, w=np.sqrt(y[6:]))

def func_pol(x, a, b, c):
    return a*x*x + b*x + c

popt, pcov = curve_fit(func_pol, x, y)
print(popt, pcov)
line  = (-0.13813199)*x*x + (9.34355559)*x -101.1623518#  + 0.8
line2 = (-0.13813199)*x*x + (9.34355559)*x -101.1623518  - 2
line3 = (-0.13813199)*x*x + (9.34355559)*x -101.1623518 + 11
line4 = (-0.15      )*x*x + (9.2       )*x -101.1623518 + 45
#line2 = (-0.15)*x[6:]*x[6:] + (10)*x[6:] -50.73920569  + 0.8
plt.plot(x, line, color='r', linestyle='--', linewidth=2)
plt.plot(x, line2, color='g', linestyle='--', linewidth=2)
plt.plot(x, line3, color='k', linestyle='--', linewidth=2)
plt.plot(x, line4, color='b', linestyle='--', linewidth=2)
plt.show()


lines  = ((var_x2_a[thr] > ((-0.13813199)*true_z2_a[thr]*true_z2_a[thr] + (9.34355559)*true_z2_a[thr] -101.1623518 - 2)) &
          (var_x2_a[thr] < ((-0.13813199)*true_z2_a[thr]*true_z2_a[thr] + (9.34355559)*true_z2_a[thr] -101.1623518 + 11)) &
          (var_x2_a[thr] < ((-0.15      )*true_z2_a[thr]*true_z2_a[thr] + (9.2       )*true_z2_a[thr] -101.1623518 + 45)))
z, v = true_z2_a[thr][sel2&lines], var_x2_a[thr][sel2&lines]

plt.scatter(z, v, s=0.5)
plt.show()
# Out:
# [ -0.10414019   6.57239578 -41.16123413] [[ 5.15696209e-06 -4.18229625e-04  8.16402684e-03]
#  [-4.18229625e-04  3.41708099e-02 -6.72336881e-01]
#  [ 8.16402684e-03 -6.72336881e-01  1.33549803e+01]]

# %%
sel2 = in_range(true_z2_a[thr], *z_lim) & in_range(var_x2_a[thr], *varx_lim)
z, v = true_z2_a[thr][sel2], var_x2_a[thr][sel2]

plt.rcParams["figure.figsize"] = 10, 6
plt.hist2d(z, v, (Zbins, Vbins), cmin=2)

x, y, yu = fitf.profileX(z, v, Zbins, z_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)
plt.title('Var X')
plt.xlabel('Z pos (mm)')
plt.ylabel('Var X (mm)')
plt.colorbar().set_label("Number of events")


#line  = (-0.13813199)*x*x + (9.34355559)*x -101.1623518#  + 0.8
line2 = (-0.13813199)*x*x + (9.34355559)*x -101.1623518  - 2
line3 = (-0.13813199)*x*x + (9.34355559)*x -101.1623518 + 11
line4 = (-0.15      )*x*x + (9.2       )*x -101.1623518 + 45
#plt.plot(x, line, color='r', linestyle='--', linewidth=2)
plt.plot(x, line2, color='r', linestyle='--', linewidth=2)
plt.plot(x, line3, color='r', linestyle='--', linewidth=2)
plt.plot(x, line4, color='r', linestyle='--', linewidth=2)
plt.show()

# %% [markdown]
# ### Coinc plane. Option2

# %%
z_lim, varx_lim = (27., 54.1), (0, 75)
plt.rcParams["figure.figsize"] = 10, 6
plt.hist2d(v, z, (Zbins, Vbins), cmin=1)

x, y, yu = fitf.profileX(v, z, Zbins, xrange=varx_lim, yrange=z_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)
plt.xlabel('Var X (mm)', fontsize=16)
plt.ylabel('Z pos (mm)', fontsize=16)
plt.colorbar().set_label("Number of events")
plt.show()

# %%
z_lim, varx_lim = (27., 54.1), (0, 70)
plt.rcParams["figure.figsize"] = 10, 6
#plt.hist2d(v, z, (Zbins, Vbins), cmin=1)

x, y, yu = fitf.profileX(v, z, Zbins, xrange=varx_lim, yrange=z_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)

sel_v = v > 50

plt.hist2d(v[~sel_v], z[~sel_v], (Zbins, Vbins), cmin=1)
plt.hist2d(v[ sel_v], z[ sel_v], (Zbins, Vbins), cmin=1)
plt.xlabel('Var X (mm)', fontsize=16)
plt.ylabel('Z pos (mm)', fontsize=16)
plt.colorbar().set_label("Number of events")
plt.axvline(x=50, c='g')
plt.xlim(0, 80)
plt.ylim(27, 54)
plt.show()

# %%
from scipy import interpolate

## Dataset 1: central points
xvals1 = np.array([50.29611650485437, 50.82115482881963, 51.24144098109352, 51.76647930505877, 52.08124680633624, 52.606285130301494, 52.815533980582536, 53.130812468063375, 53.44532447623915, 53.865355135411356, 54.28487480838018, 54.80965763924375, 55.018906489524795, 55.33341849770056, 55.54266734798162, 56.068216658150234, 56.27772100153297, 56.48696985181401, 56.80148185998979, 57.11624936126725, 57.22049054675526, 57.53576903423608, 57.74552887072049, 57.955033214103224, 58.16453755748596, 58.47904956566174, 58.79330608073583, 59.002554931016874, 59.10679611650487, 59.31655595298929, 59.52580480327032, 59.52580480327032, 59.73530914665305, 59.94481349003577, 60.15380684721514, 60.363566683699545, 60.3625447112928, 60.46678589678079, 60.571282575370475, 60.7805314256515, 61.09529892692899, 61.30454777721002, 61.30378129790496, 61.408277976494645, 61.51226366888095, 61.61650485436894, 61.615482881962194, 63.6859989780276, 63.47751660705161, 63.26954522227901, 63.166070516096084, 63.06259580991315, 63.06387327542157, 62.85487991824222, 62.750638732754226, 62.54190086867655, 62.54317833418499, 62.334184977005634, 62.12595809913134, 62.0224833929484, 61.919264179867156, 61.921308124680635, 61.8180889115994, 61.81987736331121, 61.61139499233522, 61.612672457843644, 61.613438937148715])
yvals1 = np.array([43.30097087378641, 43.05825242718447, 42.9126213592233, 42.66990291262136, 42.47572815533981, 42.23300970873787, 41.990291262135926, 41.89320388349515, 41.650485436893206, 41.456310679611654, 41.16504854368932, 40.87378640776699, 40.63106796116505, 40.38834951456311, 40.14563106796116, 40., 39.80582524271845, 39.56310679611651, 39.320388349514566, 39.126213592233015, 38.932038834951456, 38.83495145631068, 38.689320388349515, 38.49514563106796, 38.30097087378641, 38.05825242718447, 37.76699029126213, 37.52427184466019, 37.33009708737864, 37.18446601941748, 36.94174757281554, 36.94174757281554, 36.747572815533985, 36.55339805825243, 36.2621359223301, 36.116504854368934, 35.92233009708738, 35.728155339805824, 35.58252427184466, 35.33980582524272, 35.14563106796116, 34.90291262135922, 34.75728155339806, 34.6116504854369, 34.368932038834956, 34.1747572815534, 33.980582524271846, 27.378640776699026, 27.766990291262136, 28.25242718446602, 28.59223300970874, 28.932038834951456, 29.174757281553397, 29.466019417475728, 29.66019417475728, 30., 30.24271844660194, 30.533980582524272, 30.97087378640777, 31.310679611650485, 31.699029126213592, 32.087378640776706, 32.47572815533981, 32.81553398058253, 33.20388349514563, 33.44660194174757, 33.592233009708735])
##Dataset2
xvals2 = np.array([50.17833418497702, 51.01967296882985, 51.54471129279509, 52.279764946346454, 52.90878896269801, 53.32881962187021, 53.85385794583547, 54.27235564639756, 54.797649463464495, 55.11088400613185, 55.634389371486975, 56.3681655595299, 56.576647930505885, 57.3106796116505, 57.62340316811448, 57.83188553909045, 58.03985692386307, 58.457588145120084, 58.9721512519162, 58.96934082779765, 58.86177823198774, 58.75447112927952, 58.75217169136435, 58.75038323965255, 58.74782830863569, 58.74348492590701, 58.74067450178846, 58.73863055697498, 58.455544200306605, 58.77005620848239, 58.768523249872274, 58.76724578436384, 58.76494634644867])
yvals2 = np.array([40.92233009708738, 40.77669902912621, 40.53398058252427, 40.19417475728156, 39.70873786407767, 39.51456310679612, 39.271844660194176, 38.786407766990294, 38.592233009708735, 38.10679611650485, 37.57281553398059, 36.990291262135926, 36.601941747572816, 36.067961165048544, 35.48543689320388, 35.09708737864078, 34.6116504854369, 33.980582524271846, 31.74757281553398, 31.21359223300971, 30.776699029126213, 30.388349514563107, 29.95145631067961, 29.61165048543689, 29.126213592233007, 28.300970873786408, 27.766990291262136, 27.378640776699026, 33.592233009708735, 33.349514563106794, 33.05825242718447, 32.81553398058253, 32.37864077669903])

f2 = interpolate.interp1d(xvals2, yvals2, fill_value="extrapolate")
xnew = np.arange(50, 58.7, 0.1)
ynew = f2(xnew)   # use interpolation function returned by `interp1d`
plt.plot(xvals2, yvals2, 'o', xnew, ynew, '-')
plt.show()

# %%
h1 = plt.hist2d(v, z, (Zbins, Vbins))

# %%
plt.imshow(h1[0].T, origin='lower');

# %%
def search_desired_vals(matrix, n):
    searched_vals =[]
    for col in matrix:
        if n==0:
            max_and_surr = [np.argmax(col)]
        else:
            max_and_surr = [np.argmax(col)+i for i in np.arange(-n, n)]
        pe_vect = np.zeros(len(col))
        pe_vect[max_and_surr] = col[max_and_surr]
        searched_vals.append(pe_vect)
    searched_vals = np.array(searched_vals)
    return searched_vals

# %%
plt.imshow(search_desired_vals(h1[0].T, 0), origin='lower')

# %%
xs, ys   = [], []
xs0, ys0 = [], []
for j, (cols, zs) in enumerate(zip(search_desired_vals(h1[0].T, 0), np.linspace(z_lim[0], z_lim[1], 100))):
    for i, (k, vrs) in enumerate(zip(cols, np.linspace(varx_lim[0], varx_lim[1], 100))):
        if k == 0.0:
            continue
        xs.append(i)
        ys.append(j)
        #print(i,j,k,vrs,zs)
        xs0.append(vrs)
        ys0.append(zs)
xs  = np.array(xs)
ys  = np.array(ys)
xs0 = np.array(xs0)
ys0 = np.array(ys0)

# %%
f0 = interpolate.interp1d(xs0, ys0, fill_value="extrapolate")
xnew0 = np.arange(0, 66)
ynew0 = f0(xnew0)   # use interpolation function returned by `interp1d`
plt.plot(xs0, ys0, 'o', xnew0, ynew0, '-')
plt.show()

# %%
z_lim, varx_lim = (27., 54.1), (0, 75)
Zbins, Vbins = 100, 100

f2 = interpolate.interp1d(xvals2, yvals2, fill_value="extrapolate")
xnew = np.arange(50, 58.7, 0.1)
ynew = f2(xnew)   # use interpolation function returned by `interp1d`

#lines2 = ((v < 68) & (z > f2(v)))
lines2 = (v < 68)

z2, v2 = z[lines2], v[lines2]

plt.rcParams["figure.figsize"] = 10, 6
plt.hist2d(v2, z2, (Zbins, Vbins), cmin=1)

x, y, yu = fitf.profileX(v2, z2, Zbins, varx_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)
#plt.errorbar(y, x, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)

#plt.scatter(xvals2, yvals2, color='r')
plt.scatter(v, f2(v), color='b')
plt.plot(xs0, ys0-5, 'o', xnew0, ynew0, '-')
plt.scatter(xnew, ynew, color='r', s=10)
plt.ylabel('Z pos (mm)', fontsize=16)
plt.xlabel('Var X (mm)', fontsize=16)
plt.xlim(0,75)
#plt.ylim(0,100)
plt.colorbar().set_label("Number of events")
plt.show()

# %%
f3 = interpolate.interp1d(xs0, ys0, fill_value="extrapolate")

# %%
z_lim, varx_lim = (27., 54.1), (0, 75)
Zbins, Vbins = 100, 100

lines2 = ((v < 64.5) & (z > f3(v)-4) & (z < f3(v)+5))

z2, v2 = z[lines2], v[lines2]

plt.rcParams["figure.figsize"] = 10, 6
plt.hist2d(v2, z2, (Zbins, Vbins), cmin=1)

x, y, yu = fitf.profileX(v2, z2, Zbins, varx_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)

plt.plot(xs0, ys0-4, 'o', xnew0, ynew0, '-')
plt.plot(xs0, ys0+5, 'o', xnew0, ynew0, '-')
plt.ylabel('Z pos (mm)', fontsize=16)
plt.xlabel('Var X (mm)', fontsize=16)
plt.xlim(0,75)
plt.colorbar().set_label("Number of events")
plt.show()

# %%
plt.hist2d(v, z, (Zbins, Vbins), cmin=1)

x, y, yu = fitf.profileX(v2, z2, Zbins, varx_lim, drop_nan=False)
plt.errorbar(x, y, yu, np.diff(x)[0]/2, fmt="kp", ms=5, lw=2)
plt.ylabel('Z pos (mm)', fontsize=16)
plt.xlabel('Var X (mm)', fontsize=16)
plt.xlim(0,75)
plt.colorbar().set_label("Number of events")
plt.show()

# %% [markdown]
# ## Store data for the table:

# %%
VarXnBins   = [50, 100, 150, 200]
VarXRange   = (0, 65) #(0, 75)
VarXBins    = {n: np.linspace(*VarXRange, n + 1) for n       in VarXnBins}
VarXCenters = {n: shift_to_bin_centers(bins)     for n, bins in VarXBins.items()}
VarXPitch   = {n: np.diff(bins)[0]               for n, bins in VarXBins.items()}

# %%
Z_ave   = {}
Z_ave_u = {} # uncertainty
for n in ZnBins:
    x, y, yu = fitf.profileX(v2, z2, n, xrange=(0, 65), yrange=z_lim, drop_nan=False)
    Z_ave  [n] = y
    Z_ave_u[n] = yu
    print(x, y, yu)
# Out:
# [ 0.65  1.95  3.25  4.55  5.85  7.15  8.45  9.75 11.05 12.35 13.65 14.95
#  16.25 17.55 18.85 20.15 21.45 22.75 24.05 25.35 26.65 27.95 29.25 30.55
#  31.85 33.15 34.45 35.75 37.05 38.35 39.65 40.95 42.25 43.55 44.85 46.15
#  47.45 48.75 50.05 51.35 52.65 53.95 55.25 56.55 57.85 59.15 60.45 61.75
#  63.05 64.35] [53.97578812 53.83671188 53.61780548 53.46296692 53.19852066 52.92507553
#  52.67119217 52.58725739 52.38612747 52.22997665 52.00051498 51.82821274
#  51.63964844 51.42560196 51.11676025 50.87585831 50.70275116 50.4333725
#  50.22399521 50.01802063 49.74447632 49.49354553 49.20187759 49.05694962
#  48.72608948 48.59479523 48.2687149  48.00738525 47.76150894 47.34751892
#  47.07444    46.85736084 46.38926697 46.01879883 45.64344025 45.17240143
#  44.80769348 44.17063522 43.55177689 42.92307663 42.10148239 41.33150864
#  40.58596802 39.63472366 38.37856293 37.13109207 35.3829422  33.68498993
# ...

# %% [markdown]
# ## Create table

# %%
path = '/Users/carmenromoluque/nexus_petit_analysis/tof_setup/PetBox_analysis/'
Z_table_name = path+'z_var_x_table_pet_box_HamamatsuVUV_coinc_plane_cent1.h5'

class ZposT(tb.IsDescription):
    Var_x           = tb.Float32Col(pos=0)
    Zpos            = tb.Float32Col(pos=0)
    ZposUncertainty = tb.Float32Col(pos=0)

with tb.open_file(Z_table_name, "w") as output_file:
    
    if '/Zpos' in output_file:
        Zpos = output_file.root.Zpos        
    else:
        Zpos = output_file.create_group(output_file.root, "Zpos")
    
    for n in VarXBins:
        pitch      = VarXPitch[n]
        table_name = f"f{thr}pes{n}bins"

        z_table = output_file.create_table(Zpos, table_name,
                               description = ZposT,
                               title       = "z_pos",
                               filters     = tbl.filters('ZLIB4'))
    
    
        for i, var in enumerate(VarXCenters[n], start=0):
            row                    = z_table.row
            row["Var_x"]           = var
            row["Zpos"]            = Z_ave  [n][i]
            row["ZposUncertainty"] = Z_ave_u[n][i] * Z_ave[n][i] / 100
            row.append()

        table = getattr(getattr(output_file.root, 'Zpos'), table_name)
        table.attrs.VarX_bins  = n
        table.attrs.VarX_pitch = pitch

# %% [markdown]
# ### Study reco coords with the two Z maps:

# %%
evts_path = '/Users/carmenromoluque/nexus_petit_analysis/tof_setup/PetBox_analysis/tile5_centered/data_reco_info/'

timestamp_thr = [0, 0.25, 0.50, 0.75]

reco_z1, reco_z2, reco_z3 = [], [], []
true_z1, true_z2          = [], []

event_ids1           = []
event_ids2           = []
event_ids1_th_charge = []
event_ids2_th_charge = []
event_ids_times      = []

for filename in os.listdir(evts_path+'reco_info_both_planes_test_z_map_c_plane/'):
    if filename.endswith('.npz'):
        my_file = evts_path+'reco_info_both_planes_test_z_map_c_plane/'+filename        
        d = np.load(my_file, allow_pickle=True)
        for i in d[f'reco_z1']:
            reco_z1.append(i)
        for i in d[f'reco_z2']:
            reco_z2.append(i)
        for i in d[f'reco_z3']:
            reco_z3.append(i)
        for i in d[f'true_z1']:
            true_z1.append(i)
        for i in d[f'true_z2']:
            true_z2.append(i)
        for i in d[f'event_ids1']:
            event_ids1.append(i)
        for i in d[f'event_ids2']:
            event_ids2.append(i)
        for i in d[f'event_ids1_th_charge']:
            event_ids1_th_charge.append(i)
        for i in d[f'event_ids2_th_charge']:
            event_ids2_th_charge.append(i)
        for i in d[f'event_ids_times']:
            event_ids_times.append(i)

reco_z1 = np.array(reco_z1)
reco_z2 = np.array(reco_z2)
reco_z3 = np.array(reco_z3)
true_z1 = np.array(true_z1)
true_z2 = np.array(true_z2)

event_ids1           = np.array(event_ids1)
event_ids2           = np.array(event_ids2)
event_ids1_th_charge = np.array(event_ids1_th_charge)
event_ids2_th_charge = np.array(event_ids2_th_charge)
event_ids_times      = np.array(event_ids_times)

# %%
diff_z1 = (reco_z1 - true_z1)
diff_z2 = (reco_z2 - true_z2)
diff_z3 = (reco_z3 - true_z2)

# %%
print(len(reco_z2))
print(len(reco_z3))
# Out:
# 31435
# 31435

# %%
mask_ch1 = np.in1d(event_ids1, event_ids1_th_charge)
mask_ch2 = np.in1d(event_ids2, event_ids2_th_charge)

# %%
from scipy.stats import norm
from invisible_cities.core.core_functions import shift_to_bin_centers

def title_and_axes(title, x, y, fontsize):
    pylab.title(title, fontsize=fontsize)
    pylab.xlabel(x, fontsize=fontsize)
    pylab.ylabel(y, fontsize=fontsize)
    return

def create_new_figure(kwargs):
    if kwargs.setdefault("new_figure", True):
        plt.figure()
    del kwargs["new_figure"]

def hist(*args, **kwargs):
    """
    Create a figure and then the histogram
    """
    create_new_figure(kwargs)

    y, x, p = plt.hist(*args, **kwargs)
    return y, shift_to_bin_centers(x), p

def label_hist_mm(mu, mu_err, sigma, sigma_err, fwhm, fwhm_err, chi2, dec=3):
    mu_str    = f'$\mu$ = {   np.round(mu,    dec)} ± {np.round(mu_err,    dec)} mm'
    sigma_str = f'$\sigma$ = {np.round(sigma, dec)} ± {np.round(sigma_err, dec)} mm'
    fwhm_str  = f'FWHM res = {np.round(fwhm,  dec)} ± {np.round(fwhm_err,  dec)} mm'
    chi2_str  = f'$\chi^2$ = {np.round(chi2,  dec)}'
    return mu_str + '\n'+ sigma_str + '\n' + fwhm_str + '\n' + chi2_str

def fit_gaussian(variable, bins, range_hist, range_fit, max_entries, mm=True):
    
    y, x, _   = hist(variable, bins, range_hist, facecolor='skyblue')
    mu, sigma = norm.fit(variable)
    f         = fitf.fit(fitf.gauss, x, y, (max_entries,mu,sigma), fit_range=range_fit)
    fwhm      = 2.35482 * (np.sqrt(np.var(variable)))
    
    _, mu1,     sigma1     = f .values
    _, mu1_err, sigma1_err = f .errors

    fwhm1, fwhm1_err = sigma1* 2.355, sigma1_err* 2.355
    chi2 = f .chi2
    errs = np.sqrt(y)
    
    if mm:
        pylab.plot(x, fitf.gauss(x, *f.values[:3]), "r--", 
                   label=label_hist_mm(mu1, mu1_err, sigma1, sigma1_err, fwhm1, fwhm1_err, chi2))
    else:
        pylab.plot(x, fitf.gauss(x, *f.values[:3]), "r--", 
                   label=label_hist_ps(mu1, mu1_err, sigma1, sigma1_err, fwhm1, fwhm1_err, chi2, dec=1))
    plt.errorbar(x, y, yerr=errs, fmt='.k', elinewidth=0.5,  linestyle='none', capsize=2, capthick=1)
    pylab.legend(fontsize=13, loc=1)

# %%
import pylab
plt.figure(figsize=(12,8))
plt.hist(diff_z2, 150, (-20, 20), color='skyblue', histtype='step', linewidth=1.5, label=f'z1')
plt.hist(diff_z3, 150, (-20, 20), color='teal',    histtype='step', linewidth=1.5, label=f'z2')
title_and_axes(f'Diff reco - true Z (mm)', 'Z (mm)', 'Entries', fontsize=15)
plt.legend(fontsize=14)
plt.show()
# Out:
# /Users/carmenromoluque/miniconda3/envs/IC-3.7-2020-06-16/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/carmenromoluque/miniconda3/envs/IC-3.7-2020-06-16/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
print(len(diff_z2), len(diff_z2[mask_ch2]))
print(len(diff_z3), len(diff_z3[mask_ch2]))
# Out:
# 31435 28553
# 31435 28553

# %%
print('Case 1')
fit_gaussian(diff_z2, 100, (-10, 10), (-1, 1), 5000)
title_and_axes(f'Z all events', 'Diff reco - true Z (mm)', 'Entries', fontsize=15)

fit_gaussian(diff_z2[mask_ch2], 100, (-10, 10), (-1, 1), 4000)
title_and_axes(f'Z events > 200pes', 'Diff reco - true Z (mm)', 'Entries', fontsize=15)
# Out:
# Case 1

# %%
print('Case 2')
filter_nan = np.isnan(diff_z3)
fit_gaussian(diff_z3[~filter_nan], 100, (-10, 10), (-1, 1), 5000)
title_and_axes(f'Z all events', 'Diff reco - true Z (mm)', 'Entries', fontsize=15)

fit_gaussian(diff_z3[mask_ch2 &~filter_nan], 100, (-10, 10), (-1, 1), 4000)
title_and_axes(f'Z events > 200pes', 'Diff reco - true Z (mm)', 'Entries', fontsize=15)
# Out:
# Case 2

# %%
fit_gaussian(diff_z1, 100, (-10, 10), (-1, 1), 5000)
title_and_axes(f'Z all events', 'Diff reco - true Z (mm)', 'Entries', fontsize=15)

fit_gaussian(diff_z1[mask_ch1], 100, (-10, 10), (-1, 1), 4000)
title_and_axes(f'Z events > 1400pes', 'Diff reco - true Z (mm)', 'Entries', fontsize=15)
