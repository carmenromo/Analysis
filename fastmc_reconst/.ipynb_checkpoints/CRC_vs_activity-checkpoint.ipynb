# %% [markdown]
# ## In this NB we are going to study the CRC as a function of the source activity, i.e., the quality of the image as a function of the number of coincidences:

# %%
import os
import sys
import numpy as np

import matplotlib.pyplot         as plt
import mlem.mlem_reconstruct     as mr
import antea.image.fom_functions as fomf

sys.stdout = open(os.devnull, "w") ## Prevents from printing

# %%
## Configuration for plots ##
plt.rcParams["font.size"]      = 15
plt.rcParams["figure.figsize"] = 10, 7.5

## colors
tableau = [( 31, 119, 180), (174, 199, 232), (255, 127,  14), (255, 187, 120),
           ( 44, 160,  44), (152, 223, 138), (214,  39,  40), (255, 152, 150),
           (148, 103, 189), (197, 176, 213), (140,  86,  75), (196, 156, 148),
           (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),
           (188, 189,  34), (219, 219, 141), ( 23, 190, 207), (158, 218, 229), 
           (218,  60,  78), (35,  180, 203)]
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau)):
    r, g, b = tableau[i]
    tableau[i] = (r / 255., g / 255., b / 255.)

blue   = tableau[0]
green  = tableau[4]
fucsia = tableau[6]
light_red   = tableau[20]
light_blue  = tableau[21]

# %% [markdown]
# Paths:

# %%
path_to_mlem     = '/Users/carmenromoluque/tofpet3d/lib/libmlem.so'
reco_prefix_base = '/Users/carmenromoluque/nexus_petit_analysis/full-body-PET/fastsim_reco/images_fastsim/100iter/0.5th/'

# %% [markdown]
# Parameters:

# %%
th             = '0.5'
tof            = 140
n_coincidences = [8087872, 16512875, 25022441, 33515271, 42031084]
n_files        = [   1000,     2000,     3000,     4000,     5000]
n_iterations   = 20
save_every     = 2

# %% [markdown]
# MLEM reconstruction:

# %%
sys.stdout = sys.__stdout__ ## This line prevents from printing
rec_0 = mr.MLEMReconstructor(libpath=path_to_mlem)
rec_1 = mr.MLEMReconstructor(libpath=path_to_mlem)
rec_2 = mr.MLEMReconstructor(libpath=path_to_mlem)
rec_3 = mr.MLEMReconstructor(libpath=path_to_mlem)
rec_4 = mr.MLEMReconstructor(libpath=path_to_mlem)

rec_0.prefix = reco_prefix_base + f'{n_files[0]}coinc/im_th{th}_TOF{str(tof)}ps_{n_coincidences[0]}coinc_iter'
rec_1.prefix = reco_prefix_base + f'{n_files[1]}coinc/im_th{th}_TOF{str(tof)}ps_{n_coincidences[1]}coinc_iter'
rec_2.prefix = reco_prefix_base + f'{n_files[2]}coinc/im_th{th}_TOF{str(tof)}ps_{n_coincidences[2]}coinc_iter'
rec_3.prefix = reco_prefix_base + f'{n_files[3]}coinc/im_th{th}_TOF{str(tof)}ps_{n_coincidences[3]}coinc_iter'
rec_4.prefix = reco_prefix_base + f'{n_files[4]}coinc/im_th{th}_TOF{str(tof)}ps_{n_coincidences[4]}coinc_iter'

# %%
n_iterations = 16
save_every   = 2

the_imgs0 = []
for i in range(0, n_iterations, save_every):
    img = rec_0.read_image(i)
    the_imgs0.append(img)
    
the_imgs1 = []
for i in range(0, n_iterations, save_every):
    img = rec_1.read_image(i)
    the_imgs1.append(img)
    
the_imgs2 = []
for i in range(0, n_iterations, save_every):
    img = rec_2.read_image(i)
    the_imgs2.append(img)
    
the_imgs3 = []
for i in range(0, n_iterations, save_every):
    img = rec_3.read_image(i)
    the_imgs3.append(img)

the_imgs4 = []
for i in range(0, n_iterations, save_every):
    img = rec_4.read_image(i)
    the_imgs4.append(img)

# %%
the_imgs[0][0].shape
# Out:
# (60, 60, 60)

# %%
n_iter    = 0
slice_min = 25
slice_max = 35
plt.imshow(np.sum(the_imgs0[n_iter][:,:,slice_min:slice_max], axis=2).transpose(), origin='lower')
plt.colorbar()
plt.show()

# %% [markdown]
# ### Comparison between different number of icoincidences:

# %%
n_iter    = 16
slice_min = 25
slice_max = 35
fig, (ax0, ax1) = plt.subplots(1,2, figsize=(10, 5))
im0 = ax0.imshow(np.sum(the_imgs0[int(n_iter/2)-1][:,:,slice_min:slice_max], axis=2).transpose(),origin='lower')
ax0.set_title(f'{n_coincidences[0]} coincidences \n {n_iter} iterations', fontsize=18)
im1 = ax1.imshow(np.sum(the_imgs4[int(n_iter/2)-1][:,:,slice_min:slice_max], axis=2).transpose(),origin='lower')
ax1.set_title(f'{n_coincidences[4]} coincidences \n {n_iter} iterations', fontsize=18)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot contrast recovery coefficient (CRC) as a function of the activity

# %% [markdown]
# ### Image parameters

# %%
sig_intensity  =  4
bckg_intensity =  1
radial_pos     = 50.
bckg_radius    =  4.
phi0           = np.pi/6
phi_step       = np.pi/3
n_phi          = 6

hot_radii   = [4., 6.5, 8.5, 11.]
cold_radii  = [14., 18.5]
hot_angles  = [np.pi/3, 2*np.pi/3, 3*np.pi/3, 4*np.pi/3]
cold_angles = [5*np.pi/3, 6*np.pi/3]

x_size = y_size = z_size = 180
x_bins = y_bins = z_bins =  60

# %%
all_imgs = [the_imgs0, the_imgs1, the_imgs2, the_imgs3, the_imgs4]

# %%
it = 7 # would mean 16

crcs_hot_0, crcs_hot_1   = [], []
crcs_hot_2, crcs_hot_3   = [], []
crcs_cold_0, crcs_cold_1 = [], []

err_crcs_hot_0, err_crcs_hot_1   = [], []
err_crcs_hot_2, err_crcs_hot_3   = [], []
err_crcs_cold_0, err_crcs_cold_1 = [], []

for i in range(len(all_imgs)):
    crc_hot0, err_hot0 = fomf.crc_hot3d(all_imgs[i][it], sig_intensity, bckg_intensity, hot_radii[0], radial_pos,
                                        hot_angles[0], bckg_radius, phi0, phi_step, n_phi, x_size, y_size, z_size,
                                        x_bins, y_bins, z_bins)
    crc_hot1, err_hot1 = fomf.crc_hot3d(all_imgs[i][it], sig_intensity, bckg_intensity, hot_radii[1], radial_pos,
                                        hot_angles[1], bckg_radius, phi0, phi_step, n_phi, x_size, y_size, z_size,
                                        x_bins, y_bins, z_bins)
    crc_hot2, err_hot2 = fomf.crc_hot3d(all_imgs[i][it], sig_intensity, bckg_intensity, hot_radii[2], radial_pos,
                                        hot_angles[2], bckg_radius, phi0, phi_step, n_phi, x_size, y_size, z_size,
                                        x_bins, y_bins, z_bins)
    crc_hot3, err_hot3 = fomf.crc_hot3d(all_imgs[i][it], sig_intensity, bckg_intensity, hot_radii[3], radial_pos,
                                        hot_angles[3], bckg_radius, phi0, phi_step, n_phi, x_size, y_size, z_size,
                                        x_bins, y_bins, z_bins)
    crcs_hot_0.append(crc_hot0*100)
    crcs_hot_1.append(crc_hot1*100)
    crcs_hot_2.append(crc_hot2*100)
    crcs_hot_3.append(crc_hot3*100)
    
    err_crcs_hot_0.append(err_hot0*100)
    err_crcs_hot_1.append(err_hot1*100)
    err_crcs_hot_2.append(err_hot2*100)
    err_crcs_hot_3.append(err_hot3*100)
    
    crc_cold0, err_cold0 = fomf.crc_cold3d(all_imgs[i][it], cold_radii[0], radial_pos, cold_angles[0], 
                                           bckg_radius, phi0, phi_step, n_phi, x_size, y_size, z_size,
                                           x_bins, y_bins, z_bins)
    crc_cold1, err_cold1 = fomf.crc_cold3d(all_imgs[i][it], cold_radii[1], radial_pos, cold_angles[1], 
                                           bckg_radius, phi0, phi_step, n_phi, x_size, y_size, z_size,
                                           x_bins, y_bins, z_bins)
    crcs_cold_0.append(crc_cold0*100)
    crcs_cold_1.append(crc_cold1*100)
    
    err_crcs_cold_0.append(err_cold0*100)
    err_crcs_cold_1.append(err_cold1*100)

# %%
nc = np.array(n_coincidences)/1e6
ls = [f'R = {hot_radii[0]}', f'R = {hot_radii[1]}', f'R = {hot_radii[2]}', f'R = {hot_radii[3]}']
plt.errorbar(nc, crcs_hot_0, yerr=err_crcs_hot_0, xerr=None, label=ls[0], color=light_red,  marker='s', capsize=3)
plt.errorbar(nc, crcs_hot_1, yerr=err_crcs_hot_1, xerr=None, label=ls[1], color=light_blue, marker='s', capsize=3)
plt.errorbar(nc, crcs_hot_2, yerr=err_crcs_hot_2, xerr=None, label=ls[2], color=blue,       marker='s', capsize=3)
plt.errorbar(nc, crcs_hot_3, yerr=err_crcs_hot_3, xerr=None, label=ls[3], color=green,      marker='s', capsize=3)
plt.title('Hot spheres, thr=0.5 pes')
plt.xlabel(f'Number of coincidences used (x $10^6$)')
plt.ylabel('CRC (%)')
plt.ylim(0, 75)
plt.legend(loc=1);

# %%
254909/29700000
# Out:
# 0.008582794612794613
